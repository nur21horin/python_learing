# %% [markdown]
# <a href="https://colab.research.google.com/github/nur21horin/python_learing/blob/main/Untitled26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Forecasting Project Report Section
#
# *(This section will be completed once the forecasting code/notebook is provided.)*

# %% [markdown]
# ### 3. Dataset Description
#
# - **Dataset name:** `Nuclear_Power_Plant_CPS_Dataset.csv`
# - **Number of rows:** 1200
# - **Number of columns:** 13
# - **Important features:** *(Please specify important features based on your forecasting task, e.g., 'Reactor Temp (°C)', 'Coolant Flow Rate (L/s)', etc.)*
# - **Target/time-series variable:** *(Please specify the target variable you are forecasting, e.g., 'Power Output (MW)' or 'Reactor Temp (°C)')*
#
# **First 5 rows of the dataset:**
#
# | Timestamp         | Reactor Temp (°C) | Coolant Flow Rate (L/s) | Pressure (MPa) | Radiation Level (μSv/h) | Turbine Speed (RPM) | Pump Status | Power Output (MW) | Control Rod Position (%) | Steam Flow Rate (kg/s) | Vibration Level (mm/s) | Water Level (m) | Anomaly Detected |
# | :---------------- | :---------------- | :---------------------- | :------------- | :---------------------- | :------------------ | :---------- | :---------------- | :----------------------- | :--------------------- | :--------------------- | :-------------- | :--------------- |
# | 2024-10-16 10:00:00 | 357.45            | 471.88                  | 15.64          | 0.35                    | 3301.40             | ON          | 978.52            | 61.91                    | 220.49                 | 1.09                   | 5.08            | No               |
# | 2024-10-16 10:01:00 | 347.93            | 463.56                  | 16.09          | 0.38                    | 3188.52             | ON          | 934.94            | 71.73                    | 220.32                 | 2.93                   | 5.21            | No               |
# | 2024-10-16 10:02:00 | 359.72            | 471.83                  | 15.73          | 1.21                    | 2920.91             | ON          | 978.55            | 66.85                    | 205.98                 | 1.30                   | 5.20            | Yes              |
# | 2024-10-16 10:03:00 | 372.85            | 478.15                  | 15.86          | 0.60                    | 3058.42             | ON          | 1048.24           | 66.33                    | 221.16                 | 2.09                   | 5.19            | No               |
# | 2024-10-16 10:04:00 | 346.49            | 470.73                  | 16.84          | 0.83                    | 3147.45             | OFF         | 1064.99           | 62.77                    | 240.95                 | 2.03                   | 5.19            | No               |
#
# **All columns:** `['Timestamp', 'Reactor Temp (°C)', 'Coolant Flow Rate (L/s)', 'Pressure (MPa)', 'Radiation Level (μSv/h)', 'Turbine Speed (RPM)', 'Pump Status', 'Power Output (MW)', 'Control Rod Position (%)', 'Steam Flow Rate (kg/s)', 'Vibration Level (mm/s)', 'Water Level (m)', 'Anomaly Detected']`

# %%
import pandas as pd

dataset_path = '/content/Nuclear_Power_Plant_CPS_Dataset.csv'
df = pd.read_csv(dataset_path)

print(f"- Dataset name: {dataset_path.split('/')[-1]}")
print(f"- Number of rows: {df.shape[0]}")
print(f"- Number of columns: {df.shape[1]}")
print("\n- First 5 rows of the dataset:")
display(df.head())
print("\n- All columns:")
print(df.columns.tolist())
# Out:
# - Dataset name: Nuclear_Power_Plant_CPS_Dataset.csv
# - Number of rows: 1200
# - Number of columns: 13
#
# - First 5 rows of the dataset:
#              Timestamp  Reactor Temp (°C)  Coolant Flow Rate (L/s)  \
# 0  2024-10-16 10:00:00         357.450712               471.878368
# 1  2024-10-16 10:01:00         347.926035               463.558917
# 2  2024-10-16 10:02:00         359.715328               471.834463
# 3  2024-10-16 10:03:00         372.845448               478.149470
# 4  2024-10-16 10:04:00         346.487699               470.732901
#
#    Pressure (MPa)  Radiation Level (μSv/h)  Turbine Speed (RPM) Pump Status  \
# 0       15.639131                 0.352819          3301.404054          ON
# 1       16.088410                 0.384267          3188.520927          ON
# 2       15.726660                 1.214944          2920.910299          ON
# 3       15.864172                 0.600205          3058.417812          ON
# ...
