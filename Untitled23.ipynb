# %% [markdown]
# <a href="https://colab.research.google.com/github/nur21horin/python_learing/blob/main/Untitled23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
df=pd.read_csv('/content/DS 332 Lab Final Dataset - DS 332 Lab Final Dataset.csv')

# %%
df.shape
# Out:
# (400, 10)

# %%
df.head()
# Out:
#    Serial No. Degree  GRE Score  TOEFL Score  University Rating  SOP  LOR  \
# 0           1   B.Sc      337.0        118.0                4.0  4.5  4.5
# 1           2   B.Sc      324.0        107.0                4.0  4.0  4.5
# 2           3   B.Sc      316.0        104.0                3.0  3.0  3.5
# 3           4   B.Sc      322.0        110.0                3.0  3.5  2.5
# 4           5   B.Sc      314.0        103.0                2.0  2.0  3.0
#
#    CGPA  Research  Chance of Admit
# 0  9.65       1.0             0.92
# 1  8.87       1.0             0.76
# 2  8.00       1.0             0.72
# 3  8.67       NaN             0.80
# 4  8.21       0.0              NaN

# %%
df.tail()
# Out:
#      Serial No. Degree  GRE Score  TOEFL Score  University Rating  SOP  LOR  \
# 395         396   M.Sc      324.0        110.0                3.0  3.5  3.5
# 396         397   M.Sc      325.0        107.0                3.0  3.0  3.5
# 397         398   M.Sc      330.0        116.0                4.0  5.0  4.5
# 398         399   B.Sc      312.0        103.0                3.0  3.5  4.0
# 399         400    NaN      333.0        117.0                4.0  5.0  4.0
#
#      CGPA  Research  Chance of Admit
# 395  9.04       1.0             0.82
# 396  9.11       1.0             0.84
# 397  9.45       1.0             0.91
# 398  8.78       0.0             0.67
# 399  9.66       1.0             0.95

# %%
df.columns.tolist()
# Out:
# ['Serial No.',
#  'Degree',
#  'GRE Score',
#  'TOEFL Score',
#  'University Rating',
#  'SOP',
#  'LOR',
#  'CGPA',
#  'Research',
#  'Chance of Admit']

# %%
df.dtypes
# Out:
# Serial No.             int64
# Degree                object
# GRE Score            float64
# TOEFL Score          float64
# University Rating    float64
# SOP                  float64
# LOR                  float64
# CGPA                 float64
# Research             float64
# Chance of Admit      float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Serial No.            0
# Degree                1
# GRE Score            19
# TOEFL Score          13
# University Rating    15
# SOP                   5
# LOR                   8
# CGPA                 28
# Research             18
# Chance of Admit      37
# dtype: int64

# %%
df=df.dropna()

# %%
numeric_df = df.select_dtypes(include=np.number)

# %%
plt.figure(figsize=(10,7))

sns.heatmap(
    numeric_df.corr(),
    annot=True,
    cmap="coolwarm",
    fmt=".2f",
    linewidths=0.5
)
plt.title("Feature Correlation Heatmap")
plt.tight_layout()
plt.show()

# %%
correlation_matrix = numeric_df.corr()
print(correlation_matrix.round(3))
# Out:
#                    Serial No.  GRE Score  TOEFL Score  University Rating  \
# Serial No.              1.000     -0.091       -0.174             -0.188
# GRE Score              -0.091      1.000        0.826              0.649
# TOEFL Score            -0.174      0.826        1.000              0.684
# University Rating      -0.188      0.649        0.684              1.000
# SOP                    -0.185      0.622        0.644              0.743
# LOR                    -0.173      0.553        0.577              0.663
# CGPA                   -0.132      0.855        0.837              0.739
# Research               -0.051      0.632        0.522              0.469
# Chance of Admit        -0.048      0.815        0.810              0.707
#
#                      SOP    LOR   CGPA  Research  Chance of Admit
# Serial No.        -0.185 -0.173 -0.132    -0.051           -0.048
# GRE Score          0.622  0.553  0.855     0.632            0.815
# ...

# %%
target_column = "Chance of Admit"

target_correlation = correlation_matrix[target_column].sort_values(
    ascending=False
)

print(target_correlation.round(3))
# Out:
# Chance of Admit      1.000
# CGPA                 0.885
# GRE Score            0.815
# TOEFL Score          0.810
# University Rating    0.707
# SOP                  0.699
# LOR                  0.662
# Research             0.595
# Serial No.          -0.048
# Name: Chance of Admit, dtype: float64

# %%
X = df.drop(columns=[target_column])

y = df[target_column]

X = X.select_dtypes(include=np.number)

print("FEATURE ENGINEERING")

print("Independent Features (X):")
print(X.columns.tolist())

print("\nTarget Variable (y):")
print(target_column)

print("\nX Shape:", X.shape)
print("y Shape:", y.shape)
# Out:
# FEATURE ENGINEERING
# Independent Features (X):
# ['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR', 'CGPA', 'Research']
#
# Target Variable (y):
# Chance of Admit
#
# X Shape: (314, 8)
# y Shape: (314,)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

print("TRAIN-TEST SPLIT ")

print("Training Features:", X_train.shape)
print("Testing Features :", X_test.shape)

print("Training Target  :", y_train.shape)
print("Testing Target   :", y_test.shape)
# Out:
# TRAIN-TEST SPLIT
# Training Features: (251, 8)
# Testing Features : (63, 8)
# Training Target  : (251,)
# Testing Target   : (63,)

# %%
model = LinearRegression()

model.fit(X_train, y_train)

print(" MODEL TRAINING ")
print("Linear Regression model trained successfully.")

y_pred = model.predict(X_test)
# Out:
#  MODEL TRAINING
# Linear Regression model trained successfully.

# %%
print("STATISTICAL PARAMETERS ")


print("\nCoefficients / Slopes:")

for feature, coefficient in zip(X.columns, model.coef_):
    print(f"{feature}: {coefficient:.6f}")


# Y-Intercept
print("\nY-Intercept:")
print(f"{model.intercept_:.6f}")
# Out:
# STATISTICAL PARAMETERS
#
# Coefficients / Slopes:
# Serial No.: 0.000123
# GRE Score: 0.001515
# TOEFL Score: 0.003884
# University Rating: 0.011573
# SOP: 0.002606
# LOR: 0.014866
# CGPA: 0.109723
# Research: 0.022848
#
# Y-Intercept:
# -1.247350

# %%
r2 = r2_score(y_test, y_pred)

print("\nR² (Coefficient of Determination):")
print(f"{r2:.6f}")
# Out:
# R² (Coefficient of Determination):
# 0.814488

# %%
mae = mean_absolute_error(y_test, y_pred)

mse = mean_squared_error(y_test, y_pred)

rmse = np.sqrt(mse)


print("MODEL EVALUATION")

print(f"MAE  : {mae:.6f}")
print(f"MSE  : {mse:.6f}")
print(f"RMSE : {rmse:.6f}")
print(f"R²   : {r2:.6f}")
# Out:
# MODEL EVALUATION
# MAE  : 0.043271
# MSE  : 0.003631
# RMSE : 0.060255
# R²   : 0.814488

# %%
comparison = pd.DataFrame({
    "Actual": y_test.values,
    "Predicted": y_pred
})

print("ACTUAL VS PREDICTED ")
print(comparison.head(10))
# Out:
# ACTUAL VS PREDICTED
#    Actual  Predicted
# 0    0.85   0.829899
# 1    0.38   0.533876
# 2    0.80   0.844455
# 3    0.79   0.791966
# 4    0.79   0.795757
# 5    0.79   0.770552
# 6    0.50   0.630376
# 7    0.42   0.603820
# 8    0.69   0.554043
# 9    0.70   0.728279

# %%
plt.figure(figsize=(8, 6))

plt.scatter(y_test, y_pred)

# Perfect prediction line
plt.plot(
    [y_test.min(), y_test.max()],
    [y_test.min(), y_test.max()],
    linestyle="--"
)

plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs Predicted Values")

plt.tight_layout()
plt.show()

# %%
print(
    f"The Linear Regression model achieved an R² score of {r2:.3f}, "
    f"which indicates that approximately {r2 * 100:.2f}% of the "
    f"variation in the target variable is explained by the selected features."
)
print(
    f"The model has a Mean Absolute Error (MAE) of {mae:.3f} "
    f"and a Root Mean Squared Error (RMSE) of {rmse:.3f}."
)
if r2 >= 0.80:
    print(
        "Overall, the model shows a strong fit to the data "
        "and provides relatively accurate predictions."
    )
elif r2 >= 0.60:
    print(
        "Overall, the model shows a moderate fit to the data. "
        "The predictions are reasonably useful but there may be room for improvement."
    )
elif r2 >= 0:
    print(
        "Overall, the model shows a relatively weak fit. "
        "Additional features or a different modeling approach may improve performance."
    )
else:
    print(
        "The model performs poorly on the test data, as indicated by "
        "the negative R² value."
    )
# Out:
# The Linear Regression model achieved an R² score of 0.814, which indicates that approximately 81.45% of the variation in the target variable is explained by the selected features.
# The model has a Mean Absolute Error (MAE) of 0.043 and a Root Mean Squared Error (RMSE) of 0.060.
# Overall, the model shows a strong fit to the data and provides relatively accurate predictions.
